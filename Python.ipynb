# %%
print("Hello world!!")
# Out:
# Hello world!!

# %%
age =20
print(age)
# Out:
# 20

# %%
age = 'a'
print(age)
# Out:
# a

# %%
age = False
print(age)
# Out:
# False

# %%
name = input("What is your name? " )
print("Hi "+name)
# Out:
# Hi

# %%
birth_year = input()
age = 2024 - birth_year
print(age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 birth_year = input()
# ----> 2 age = 2024 - birth_year
#       3 print(age)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
birth_year = input()
age = 2024 - int(birth_year)
print(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 birth_year = input()
# ----> 2 age = 2024 - int(birth_year)
#       3 print(age)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
birth_year = input()
age = 2024 - float(birth_year)
print(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 birth_year = input()
# ----> 2 age = 2024 - float(birth_year)
#       3 print(age)
#
# ValueError: could not convert string to float: ''

# %%
birth_year = input()
age = str(2024) - birth_year
print(age)
# Out:
#  2004
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 birth_year = input()
# ----> 2 age = str(2024) - birth_year
#       3 print(age)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
birth_year = input()
age = str(2024) + birth_year
print(age)
# Out:
# 2024

# %%
first = float(input("first: "))
second = float(input("second: "))
sum = first + second
print("sum : " + str(sum))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 first = float(input("first: "))
#       2 second = float(input("second: "))
#       3 sum = first + second
#
# ValueError: could not convert string to float: ''

# %%
course = 'ython'
print(course.capitalize())
print(course.find('thon'))
# Out:
# Ython
# 1

# %%
print('thon' in course)
# Out:
# True

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(10//3)
# Out:
# 3

# %%
print(10 ** 6)
# Out:
# 1000000

# %%
x=10
x**=6
print(x)
# Out:
# 1000000

# %%
x=1
print(x>-1 or x<2)
# Out:
# True

# %%
print(x>-1 and x<1)
# Out:
# False

# %%
print(not x<-1)
# Out:
# True

# %%
print(not x>-1)
# Out:
# False

# %%
print('it's a great day')
# Out:
#   Cell In[1], line 1
#     print('it's a great day')
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("it's a great day")
# Out:
# it's a great day

# %%
temp = float(input("what's the temperature? "))
if temp>40:
    print("it's too hot!!")
elif temp>20:
    print("it's moderately hot ")
else :
    print("it's cool")

print("Done")
# Out:
# what's the temperature?  20
# it's cool
# Done

# %%
i=1
while i<=5:
    print(i * '*')
    i+=1
# Out:
# *
# **
# ***
# ****
# *****

# %%
numbers = [1,2,3,4,5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(numbers[2])
print(numbers[-2])
# Out:
# 3
# 4

# %%
print(numbers [1:4])
# Out:
# [2, 3, 4]

# %%
numbers = [1,2,3,4,5]
numbers.insert(2,"Hero")
print(numbers)
# Out:
# [1, 2, 'Hero', 3, 4, 5]

# %%
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 'Hero', 3, 4, 5, 6]

# %%
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 'Hero', 4, 5, 6]

# %%
print(2 in numbers)
# Out:
# True

# %%
print(len(numbers))
# Out:
# 6

# %%
for x in numbers:
    print(x)
# Out:
# 1
# 2
# Hero
# 4
# 5
# 6

# %%
for n in range(5):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for n in range(5,10):
    print(n)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for n in range(10,5,-1):
    print(n)
# Out:
# 10
# 9
# 8
# 7
# 6

# %%
numbers = (1,2,3,4,5)

# %%
import pandas as pd
from io import StringIO,BytesIO

# %%
data = ('col1,col2,col3\n'
        '1,2,3\n'
        '4,5,6')

# %%
type(data)
# Out:
# str

# %%
StringIO()

# %%
pd.read_csv(StringIO(data))
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6

# %%
df = pd.read_csv(StringIO(data), usecols=['col1','col2'])
df
# Out:
#    col1  col2
# 0     1     2
# 1     4     5

# %%
df.to_csv('test2.csv')

# %%
df['col1'][0]
# Out:
# 1

# %%
df = pd.read_csv(StringIO(data),dtype='float')
df['col1'][0]
# Out:
# 1.0

# %%
df['col1']
# Out:
# 0    1.0
# 1    4.0
# Name: col1, dtype: float64

# %%
df = pd.read_csv(StringIO(data),dtype={'col1':float,'col2':str})
df
# Out:
#    col1 col2  col3
# 0   1.0    2     3
# 1   4.0    5     6

# %%
data = ('a,b,c\n'
        '4,apple,bat,\n'
        '8,orange,cow,')

# %%
pd.read_csv(StringIO(data))
# Out:
#         a    b   c
# 4   apple  bat NaN
# 8  orange  cow NaN

# %%
pd.read_csv(StringIO(data),index_col=False)
# Out:
#    a       b    c
# 0  4   apple  bat
# 1  8  orange  cow

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
a = np.arange(1,10)
b = np.arange(11,20)

# %%
plt.scatter(a,b,c='b')

plt.savefig('test.png')

# %%
b = a*a

# %%
plt.plot(a,b,'r*-')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.arange(0,2*np.pi,0.01)
y = np.sin(x)
plt.plot(x,y)

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])     #as data set contains columns which are categorical values (non-integers)
numeric_df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.pairplot(df,hue='sex')

# %%
sns.displot(df['tip'],bins=10)

# %%
## Count plot

sns.countplot(x = 'sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x = 'sex',y = 'tip',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day", y="total_bill", data=df,palette='rainbow')
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_20728\1105033674.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=df,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df,palette='rainbow',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y="total_bill", x="day", data=df,palette='rainbow')
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_20728\940114709.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y="total_bill", x="day", data=df,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>
